# %% [markdown]
# # ASSIGNMENT 06(A): CONFIDENCE INTERVAL

# %% [markdown]
# # 1.Build 99% Confidence Interval Using Sample Standard Deviation

# %%
import numpy as np
from scipy import stats

# %%
data = [1.13, 1.55, 1.43, 0.92, 1.25, 1.36, 1.32, 0.85, 1.07, 1.48, 1.20, 1.33, 1.18, 1.22, 1.29]
data
# Out:
# [1.13,
#  1.55,
#  1.43,
#  0.92,
#  1.25,
#  1.36,
#  1.32,
#  0.85,
#  1.07,
#  1.48,
#  1.2,
#  1.33,
#  1.18,
#  1.22,
#  1.29]

# %%
mean = np.mean(data)
std = np.std(data, ddof=1)
n = len(data)
df = n - 1
t_critical = stats.t.ppf(1 - 0.005, df)
margin_a = t_critical * s / np.sqrt(n)
ci_a_lower = mean - margin_a
ci_a_upper = mean + margin_a

# %%
print("Part a:")
print(f"Mean: {mean:.4f}")
print(f"Sample Std Dev: {std:.4f}")
print(f"t-critical: {t_critical:.4f}")
print(f"CI: {ci_a_lower:.4f},{ci_a_upper:.4f}")
# Out:
# Part a:
# Mean: 1.2387
# Sample Std Dev: 0.1932
# t-critical: 2.9768
# CI: 1.0902,1.3871

# %% [markdown]
# * data - Data List
# * mean - Mean of list
# * std - Sample Standard Deviation
# * n - Number of Samples
# * df - Degree of Freedom
# * t_critical - t-critical value for 99% Confidence Interval
# * margin_a - margin of error
# * ci_a_lower - Lower bound of Confidence Interval
# * ci_a_upper - Upper bound of Confidence Interval

# %% [markdown]
# # 2. Build 99% Confidence Interval Using Known Population Standard Deviation

# %%
sigma = 0.2
z_critical = stats.norm.ppf(1 - 0.005)
margin_b = z_critical * sigma / np.sqrt(n)
ci_b_lower = mean - margin_b
ci_b_upper = mean + margin_b

# %%
print("Part b:")
print(f"z-critical: {z_critical:.4f}")
print(f"CI: {ci_b_lower:.4f},{ci_a_upper:.4f}")
# Out:
# Part b:
# z-critical: 2.5758
# CI: 1.1057,1.3871

# %% [markdown]
# * sigma - Sets known population std dev (given 0.2)
# * z_critical - z-critical for 99% Confidence Interval
# * margin_b - Margin of error
# * ci_b_lower - Lower bound for b
# * ci_b_upper - Upper bound for b
